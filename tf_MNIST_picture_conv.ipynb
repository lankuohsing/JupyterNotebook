# %%
#packages
import tensorflow as tf
import pandas as pd
import numpy as np
from numpy import random as nr
from py_dense_to_onehot import dense_to_one_hot
from py_read_MNIST import read_mnist_pictures
import types

# %%
#一些常量的定义
img_size=28*28
num_class=10
training_iters=200000
train_size=0.8
n_hidden_1 = 256 # 1st layer number of features
n_hidden_2 = 256 # 2nd layer number of features
training_epochs=15
display_step=10
learning_rate=1e-3
batch_size=128
dropout1=0.75

# %%
training_images,training_labels,num_train=read_mnist_pictures('trainimage')
testing_images,testing_labels,num_test=read_mnist_pictures('testimage')
# Out:
# The size of trainimage images: 60000
# The size of testimage images: 10000

# %%
training_labels_onehot=dense_to_one_hot(training_labels,num_class)
testing_labels_onehot=dense_to_one_hot(testing_labels,num_class)

# %%
#Create some wrappers for simplicity
def conv2d(x,W,b,strides=1):
    x=tf.nn.conv2d(x,W,strides=[1,strides,strides,1],padding='SAME')#SAME表示卷积核可以停留在图像边缘
    return tf.nn.relu(x)

def maxpool2d(x,k=2):
    return tf.nn.max_pool(x,ksize=[1,k,k,1],strides=[1,k,k,1],padding='SAME')

#Create model
def conv_net(x,W,b,keep_prob=1.):
    #Reshape input image
    x=tf.reshape(x,shape=[-1,28,28,1])
    
    #Convolution Layer 
    conv1=conv2d(x,W['wc1'],b['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)
    # Convolution Layer
    conv2 = conv2d(conv1, W['wc2'],b['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)
    
    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, W['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, W['wd1']), b['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, keep_prob)
    # Output, class prediction
    out = tf.add(tf.matmul(fc1, W['out']), b['out'])
    return out

# %%
#Weights and bias
W={
    #5x5 conv,1 input, 32outputs
    'wc1': tf.Variable(tf.random_normal([5,5,1,32])),
    #5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5,5,32,64])),
    #Fully connected, 7x7x64 inputs, 2014 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64,1024])),
    'out': tf.Variable(tf.random_normal([1024,num_class]))
}
b = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([num_class]))
}
x=tf.placeholder(tf.float32,[None,img_size])
y_ = tf.placeholder(tf.float32, [None,num_class])#正确的标签
keep_prob = tf.placeholder(tf.float32)

# %%
# Construct model
y = conv_net(x, W, b, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y, labels=y_))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(y, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_indices=nr.choice(range(num_train),batch_size)
        batch_x=training_images[batch_indices,:]
        batch_y=training_labels_onehot[batch_indices,:]
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y_: batch_y,keep_prob: dropout1})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y_: batch_y,
                                                             keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: testing_images,
                                      y_: testing_labels_onehot,
                                     keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 4490163.000000, Training Accuracy= 0.24219
# Iter 2560, Minibatch Loss= 1881457.000000, Training Accuracy= 0.53125
# Iter 3840, Minibatch Loss= 1326718.250000, Training Accuracy= 0.60938
# Iter 5120, Minibatch Loss= 701187.250000, Training Accuracy= 0.76562
# Iter 6400, Minibatch Loss= 909336.750000, Training Accuracy= 0.78906
# Iter 7680, Minibatch Loss= 907619.750000, Training Accuracy= 0.75000
# Iter 8960, Minibatch Loss= 509017.062500, Training Accuracy= 0.85156
# Iter 10240, Minibatch Loss= 282717.750000, Training Accuracy= 0.89062
# Iter 11520, Minibatch Loss= 413563.812500, Training Accuracy= 0.88281
# Iter 12800, Minibatch Loss= 279931.250000, Training Accuracy= 0.91406
# Iter 14080, Minibatch Loss= 164084.671875, Training Accuracy= 0.94531
# Iter 15360, Minibatch Loss= 639894.750000, Training Accuracy= 0.87500
# Iter 16640, Minibatch Loss= 281319.000000, Training Accuracy= 0.89062
# Iter 17920, Minibatch Loss= 217443.390625, Training Accuracy= 0.94531
# Iter 19200, Minibatch Loss= 162171.546875, Training Accuracy= 0.92188
# Iter 20480, Minibatch Loss= 232188.000000, Training Accuracy= 0.92969
# Iter 21760, Minibatch Loss= 104418.625000, Training Accuracy= 0.95312
# Iter 23040, Minibatch Loss= 276819.562500, Training Accuracy= 0.87500
# Iter 24320, Minibatch Loss= 371080.312500, Training Accuracy= 0.89062
# Iter 25600, Minibatch Loss= 430347.281250, Training Accuracy= 0.88281
# Iter 26880, Minibatch Loss= 149274.687500, Training Accuracy= 0.92969
# Iter 28160, Minibatch Loss= 162977.921875, Training Accuracy= 0.92969
# Iter 29440, Minibatch Loss= 189755.375000, Training Accuracy= 0.90625
# Iter 30720, Minibatch Loss= 159510.500000, Training Accuracy= 0.96094
# Iter 32000, Minibatch Loss= 159558.984375, Training Accuracy= 0.92188
# Iter 33280, Minibatch Loss= 71479.828125, Training Accuracy= 0.94531
# Iter 34560, Minibatch Loss= 191096.656250, Training Accuracy= 0.90625
# Iter 35840, Minibatch Loss= 175656.859375, Training Accuracy= 0.94531
# Iter 37120, Minibatch Loss= 113810.789062, Training Accuracy= 0.92969
# Iter 38400, Minibatch Loss= 109897.281250, Training Accuracy= 0.96094
# Iter 39680, Minibatch Loss= 108731.539062, Training Accuracy= 0.94531
# Iter 40960, Minibatch Loss= 147550.296875, Training Accuracy= 0.94531
# Iter 42240, Minibatch Loss= 163572.531250, Training Accuracy= 0.94531
# Iter 43520, Minibatch Loss= 109996.289062, Training Accuracy= 0.94531
# Iter 44800, Minibatch Loss= 66841.984375, Training Accuracy= 0.96875
# Iter 46080, Minibatch Loss= 139498.406250, Training Accuracy= 0.93750
# Iter 47360, Minibatch Loss= 42993.281250, Training Accuracy= 0.96875
# Iter 48640, Minibatch Loss= 182815.125000, Training Accuracy= 0.92969
# Iter 49920, Minibatch Loss= 285226.718750, Training Accuracy= 0.92969
# Iter 51200, Minibatch Loss= 73229.953125, Training Accuracy= 0.94531
# Iter 52480, Minibatch Loss= 151086.062500, Training Accuracy= 0.95312
# Iter 53760, Minibatch Loss= 188298.843750, Training Accuracy= 0.92188
# Iter 55040, Minibatch Loss= 165261.187500, Training Accuracy= 0.94531
# Iter 56320, Minibatch Loss= 208862.468750, Training Accuracy= 0.95312
# Iter 57600, Minibatch Loss= 71767.515625, Training Accuracy= 0.96094
# Iter 58880, Minibatch Loss= 209682.109375, Training Accuracy= 0.91406
# Iter 60160, Minibatch Loss= 128780.382812, Training Accuracy= 0.97656
# Iter 61440, Minibatch Loss= 95010.015625, Training Accuracy= 0.93750
# Iter 62720, Minibatch Loss= 90984.281250, Training Accuracy= 0.94531
# Iter 64000, Minibatch Loss= 100631.335938, Training Accuracy= 0.93750
# Iter 65280, Minibatch Loss= 15983.121094, Training Accuracy= 0.97656
# Iter 66560, Minibatch Loss= 121308.132812, Training Accuracy= 0.93750
# Iter 67840, Minibatch Loss= 24397.726562, Training Accuracy= 0.97656
# Iter 69120, Minibatch Loss= 108944.312500, Training Accuracy= 0.96875
# Iter 70400, Minibatch Loss= 167226.531250, Training Accuracy= 0.93750
# Iter 71680, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 72960, Minibatch Loss= 49425.531250, Training Accuracy= 0.96094
# Iter 74240, Minibatch Loss= 150487.968750, Training Accuracy= 0.95312
# Iter 75520, Minibatch Loss= 127607.187500, Training Accuracy= 0.96094
# Iter 76800, Minibatch Loss= 232652.968750, Training Accuracy= 0.92188
# Iter 78080, Minibatch Loss= 106516.117188, Training Accuracy= 0.95312
# Iter 79360, Minibatch Loss= 37935.597656, Training Accuracy= 0.97656
# Iter 80640, Minibatch Loss= 53097.332031, Training Accuracy= 0.96875
# Iter 81920, Minibatch Loss= 77703.789062, Training Accuracy= 0.96875
# Iter 83200, Minibatch Loss= 78243.875000, Training Accuracy= 0.95312
# Iter 84480, Minibatch Loss= 143343.203125, Training Accuracy= 0.92969
# Iter 85760, Minibatch Loss= 74168.687500, Training Accuracy= 0.96875
# Iter 87040, Minibatch Loss= 121188.421875, Training Accuracy= 0.96875
# Iter 88320, Minibatch Loss= 75068.968750, Training Accuracy= 0.96094
# Iter 89600, Minibatch Loss= 73827.109375, Training Accuracy= 0.96094
# Iter 90880, Minibatch Loss= 79418.984375, Training Accuracy= 0.94531
# Iter 92160, Minibatch Loss= 117533.500000, Training Accuracy= 0.92969
# Iter 93440, Minibatch Loss= 27983.464844, Training Accuracy= 0.96875
# Iter 94720, Minibatch Loss= 70511.085938, Training Accuracy= 0.97656
# Iter 96000, Minibatch Loss= 24134.722656, Training Accuracy= 0.97656
# Iter 97280, Minibatch Loss= 23138.300781, Training Accuracy= 0.98438
# Iter 98560, Minibatch Loss= 31352.082031, Training Accuracy= 0.97656
# Iter 99840, Minibatch Loss= 120236.148438, Training Accuracy= 0.95312
# Iter 101120, Minibatch Loss= 7763.708984, Training Accuracy= 0.98438
# Iter 102400, Minibatch Loss= 134449.515625, Training Accuracy= 0.95312
# Iter 103680, Minibatch Loss= 27552.822266, Training Accuracy= 0.96875
# Iter 104960, Minibatch Loss= 98360.406250, Training Accuracy= 0.94531
# Iter 106240, Minibatch Loss= 25199.623047, Training Accuracy= 0.98438
# Iter 107520, Minibatch Loss= 49537.460938, Training Accuracy= 0.96875
# Iter 108800, Minibatch Loss= 136137.781250, Training Accuracy= 0.94531
# Iter 110080, Minibatch Loss= 70334.343750, Training Accuracy= 0.95312
# Iter 111360, Minibatch Loss= 47588.101562, Training Accuracy= 0.96094
# Iter 112640, Minibatch Loss= 43540.968750, Training Accuracy= 0.96875
# Iter 113920, Minibatch Loss= 74864.367188, Training Accuracy= 0.94531
# Iter 115200, Minibatch Loss= 138808.609375, Training Accuracy= 0.92969
# Iter 116480, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 117760, Minibatch Loss= 45927.882812, Training Accuracy= 0.97656
# Iter 119040, Minibatch Loss= 21911.066406, Training Accuracy= 0.97656
# Iter 120320, Minibatch Loss= 104331.218750, Training Accuracy= 0.95312
# Iter 121600, Minibatch Loss= 78749.671875, Training Accuracy= 0.95312
# Iter 122880, Minibatch Loss= 44372.593750, Training Accuracy= 0.96094
# Iter 124160, Minibatch Loss= 129920.109375, Training Accuracy= 0.93750
# Iter 125440, Minibatch Loss= 25305.634766, Training Accuracy= 0.98438
# Iter 126720, Minibatch Loss= 32249.066406, Training Accuracy= 0.97656
# Iter 128000, Minibatch Loss= 94084.375000, Training Accuracy= 0.94531
# Iter 129280, Minibatch Loss= 60943.828125, Training Accuracy= 0.95312
# Iter 130560, Minibatch Loss= 19480.642578, Training Accuracy= 0.96875
# Iter 131840, Minibatch Loss= 50088.148438, Training Accuracy= 0.97656
# Iter 133120, Minibatch Loss= 46637.609375, Training Accuracy= 0.96875
# Iter 134400, Minibatch Loss= 30413.054688, Training Accuracy= 0.98438
# Iter 135680, Minibatch Loss= 965.882812, Training Accuracy= 0.99219
# Iter 136960, Minibatch Loss= 26868.189453, Training Accuracy= 0.97656
# Iter 138240, Minibatch Loss= 65697.992188, Training Accuracy= 0.96094
# Iter 139520, Minibatch Loss= 34238.046875, Training Accuracy= 0.96094
# Iter 140800, Minibatch Loss= 54606.500000, Training Accuracy= 0.97656
# Iter 142080, Minibatch Loss= 33618.679688, Training Accuracy= 0.96875
# Iter 143360, Minibatch Loss= 30799.894531, Training Accuracy= 0.97656
# Iter 144640, Minibatch Loss= 37543.355469, Training Accuracy= 0.96875
# Iter 145920, Minibatch Loss= 8669.136719, Training Accuracy= 0.98438
# Iter 147200, Minibatch Loss= 54040.476562, Training Accuracy= 0.97656
# Iter 148480, Minibatch Loss= 42194.816406, Training Accuracy= 0.98438
# Iter 149760, Minibatch Loss= 56156.203125, Training Accuracy= 0.97656
# Iter 151040, Minibatch Loss= 50899.937500, Training Accuracy= 0.96094
# Iter 152320, Minibatch Loss= 18703.744141, Training Accuracy= 0.98438
# Iter 153600, Minibatch Loss= 69243.000000, Training Accuracy= 0.96875
# Iter 154880, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 156160, Minibatch Loss= 27484.943359, Training Accuracy= 0.96875
# Iter 157440, Minibatch Loss= 63242.804688, Training Accuracy= 0.94531
# Iter 158720, Minibatch Loss= 30972.767578, Training Accuracy= 0.96875
# Iter 160000, Minibatch Loss= 48913.445312, Training Accuracy= 0.97656
# Iter 161280, Minibatch Loss= 57267.941406, Training Accuracy= 0.96875
# Iter 162560, Minibatch Loss= 6039.367188, Training Accuracy= 0.99219
# Iter 163840, Minibatch Loss= 39010.277344, Training Accuracy= 0.97656
# Iter 165120, Minibatch Loss= 10293.937500, Training Accuracy= 0.98438
# Iter 166400, Minibatch Loss= 46941.386719, Training Accuracy= 0.96094
# Iter 167680, Minibatch Loss= 7400.931641, Training Accuracy= 0.99219
# Iter 168960, Minibatch Loss= 31243.244141, Training Accuracy= 0.98438
# Iter 170240, Minibatch Loss= 96203.632812, Training Accuracy= 0.96094
# Iter 171520, Minibatch Loss= 12768.701172, Training Accuracy= 0.98438
# Iter 172800, Minibatch Loss= 52540.328125, Training Accuracy= 0.97656
# Iter 174080, Minibatch Loss= 74562.953125, Training Accuracy= 0.96094
# Iter 175360, Minibatch Loss= 15162.810547, Training Accuracy= 0.98438
# Iter 176640, Minibatch Loss= 6551.820312, Training Accuracy= 0.99219
# Iter 177920, Minibatch Loss= 43144.171875, Training Accuracy= 0.96875
# Iter 179200, Minibatch Loss= 34492.019531, Training Accuracy= 0.99219
# Iter 180480, Minibatch Loss= 50784.546875, Training Accuracy= 0.95312
# Iter 181760, Minibatch Loss= 32446.984375, Training Accuracy= 0.97656
# Iter 183040, Minibatch Loss= 51161.097656, Training Accuracy= 0.96875
# Iter 184320, Minibatch Loss= 20854.029297, Training Accuracy= 0.98438
# Iter 185600, Minibatch Loss= 38482.953125, Training Accuracy= 0.98438
# Iter 186880, Minibatch Loss= 7824.066406, Training Accuracy= 0.98438
# Iter 188160, Minibatch Loss= 39278.523438, Training Accuracy= 0.97656
# Iter 189440, Minibatch Loss= 59948.296875, Training Accuracy= 0.97656
# Iter 190720, Minibatch Loss= 25165.882812, Training Accuracy= 0.97656
# Iter 192000, Minibatch Loss= 13338.306641, Training Accuracy= 0.97656
# Iter 193280, Minibatch Loss= 53405.671875, Training Accuracy= 0.98438
# Iter 194560, Minibatch Loss= 9805.601562, Training Accuracy= 0.99219
# Iter 195840, Minibatch Loss= 0.000000, Training Accuracy= 1.00000
# Iter 197120, Minibatch Loss= 52090.949219, Training Accuracy= 0.96875
# Iter 198400, Minibatch Loss= 54192.050781, Training Accuracy= 0.96875
# Iter 199680, Minibatch Loss= 457.154297, Training Accuracy= 0.99219
# Optimization Finished!
# Testing Accuracy: 0.9715
